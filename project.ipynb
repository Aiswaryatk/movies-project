# %%
#!/usr/bin/env python
# coding: utf-8

# %% [markdown]
# <img src="http://cfs22.simplicdn.net/ice9/new_logo.svgz "/><br>
# <br>
# # Project 04: Movielens Dataset Analysis<br>
# <br>
# You don't need to limit yourself to the number of rows/cells provided. You can add additional rows in each section to add more lines of code.<br>
# <br>
# **Happy coding!**

# %% [markdown]
# In[1]:

# %%
import pandas as pd
import numpy as np
#import skkit as sk

# %% [markdown]
# In[40]:

# %% [markdown]
# ƒ˜	Data acquisition of the movielens dataset     â€¢	users dataset â€¢	rating dataset *	movies dataset

# %%
users=pd.read_table("D:\\movies-project\\users.dat",engine='python',sep='::')
ratings=pd.read_table("D:\\movies-project\\ratings.dat",engine='python',sep='::')
movies=pd.read_csv("D:\\movies-project\\movies.dat",sep='::', engine='python')

# %% [markdown]
# In[3]:

# %%
users.head() #UserID::Gender::Age::Occupation::Zip-code

# %% [markdown]
# In[4]:

# %%
ratings.head() #UserID::MovieID::Rating::Timestamp

# %% [markdown]
# In[41]:

# %%
movies.head()  #MovieID::Title::Genres

# %% [markdown]
# In[66]:

# %% [markdown]
# serID::Gender::Age::Occupation::Zip-code<br>
# rame=pd.DataFrame([Cov], columns = ["Sequence", "Start", "End", "Coverage"])

# %%
users1=pd.DataFrame(data=users,columns=['UserID','Gender','Age','Occupation','Zip-code'])
users1

# %% [markdown]
# In[31]:

# %%
d={'col1':[1,2,3,4] ,'col2':['a','s','c','d']}
df=pd.DataFrame(data=d)
df

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# ƒ˜	Perform the Exploratory Data Analysis (EDA) for the users dataset<br>
# €¢	Visualize user age distribution

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:
